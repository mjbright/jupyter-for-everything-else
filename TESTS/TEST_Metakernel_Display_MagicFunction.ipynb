# %% [markdown]
# # TEST notebook
#
# This notebook is for testing the [https://github.com/mjbright/metakernel](https://github.com/mjbright/metakernel) kernel module display extensions.
#
# 2016-07-09: Working, all images display, notebook can be run repeatedly
#
# Tests:
# - display of local file
#   - from stdin
#   - from filename argument
# - display of file from url
# - display of image from base64-encoded data

# %%
display < /cygdrive/c/HP/drivers/touchpad/img_clicking.png

# %%
cat /cygdrive/c/HP/drivers/touchpad/img_clicking.png | display

# %%
display /cygdrive/c/HP/drivers/touchpad/img_clicking.png

# %%
display http://smallbang.fr/wp-content/themes/nemesis/images/icon_link.png
# Out:
# --2016-07-09 15:09:45--  http://smallbang.fr/wp-content/themes/nemesis/images/icon_link.png
# Resolving smallbang.fr (smallbang.fr)... 91.121.170.226
# Connecting to smallbang.fr (smallbang.fr)|91.121.170.226|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3654 (3.6K) [image/png]
# Saving to: ‘STDOUT’
#
#      0K ...                                                   100% 27.4M=0s
#
# 2016-07-09 15:09:45 (27.4 MB/s) - written to stdout [3654/3654]

# %%
display http://thesuntoday.wpengine.netdna-cdn.com/wp-content/uploads/2011/04/Sun-April62011.001.001.png
# Out:
# --2016-07-09 15:09:45--  http://thesuntoday.wpengine.netdna-cdn.com/wp-content/uploads/2011/04/Sun-April62011.001.001.png
# Resolving thesuntoday.wpengine.netdna-cdn.com (thesuntoday.wpengine.netdna-cdn.com)... 94.31.29.96
# Connecting to thesuntoday.wpengine.netdna-cdn.com (thesuntoday.wpengine.netdna-cdn.com)|94.31.29.96|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 804810 (786K) [image/png]
# Saving to: ‘STDOUT’
#
#      0K .......... .......... .......... .......... ..........  6%  172K 4s
#     50K .......... .......... .......... .......... .......... 12%  164K 4s
#    100K .......... .......... .......... .......... .......... 19%  163K 4s
#    150K .......... .......... .......... .......... .......... 25%  154K 4s
#    200K .......... .......... .......... .......... .......... 31%  176K 3s
#    250K .......... .......... .......... .......... .......... 38%  168K 3s
#    300K .......... .......... .......... .......... .......... 44%  161K 3s
# ...

# %%
display 'http://images6.fanpop.com/image/photos/38500000/beautiful-wallpaper-2-beautiful-pictures-38538867-2560-1600.jpg'
# Out:
# --2016-07-09 15:09:51--  http://images6.fanpop.com/image/photos/38500000/beautiful-wallpaper-2-beautiful-pictures-38538867-2560-1600.jpg
# Resolving images6.fanpop.com (images6.fanpop.com)... 104.25.113.32, 104.25.112.32
# Connecting to images6.fanpop.com (images6.fanpop.com)|104.25.113.32|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 638420 (623K) [image/jpeg]
# Saving to: ‘STDOUT’
#
#      0K .......... .......... .......... .......... ..........  8%  180K 3s
#     50K .......... .......... .......... .......... .......... 16%  165K 3s
#    100K .......... .......... .......... .......... .......... 24%  163K 3s
#    150K .......... .......... .......... .......... .......... 32%  169K 3s
#    200K .......... .......... .......... .......... .......... 40%  177K 2s
#    250K .......... .......... .......... .......... .......... 48%  161K 2s
#    300K .......... .......... .......... .......... .......... 56%  161K 2s
# ...

# %% [markdown]
# # Display of base64-encoded image

# %%
display 'data:image/jpeg;base64,...'

# %% [markdown]
# # Display image-data on stdin

# %%
curl -s 'http://thesuntoday.wpengine.netdna-cdn.com/wp-content/uploads/2011/04/Sun-April62011.001.001.png' | display

# %%
wget -O - 'http://thesuntoday.wpengine.netdna-cdn.com/wp-content/uploads/2011/04/Sun-April62011.001.001.png' | display
# Out:
# --2016-07-09 15:10:01--  http://thesuntoday.wpengine.netdna-cdn.com/wp-content/uploads/2011/04/Sun-April62011.001.001.png
# Resolving thesuntoday.wpengine.netdna-cdn.com (thesuntoday.wpengine.netdna-cdn.com)... 94.31.29.96
# Connecting to thesuntoday.wpengine.netdna-cdn.com (thesuntoday.wpengine.netdna-cdn.com)|94.31.29.96|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 804810 (786K) [image/png]
# Saving to: ‘STDOUT’
#
#      0K .......... .......... .......... .......... ..........  6%  171K 4s
#     50K .......... .......... .......... .......... .......... 12% 77.1K 6s
#    100K .......... .......... .......... .......... .......... 19% 1.57M 4s
#    150K .......... .......... .......... .......... .......... 25%  241K 3s
#    200K .......... .......... .......... .......... .......... 31%  165K 3s
#    250K .......... .......... .......... .......... .......... 38%  163K 3s
#    300K .......... .......... .......... .......... .......... 44%  169K 3s
# ...
